# %%
import numpy as np

"""
    numpy.random.random(size=None)  返回一个或一组从0-1均匀分布的随机样本
    size； 输出数组的形状，它可以时整数也可以时元组
"""

print(np.random.random())
print(np.random.random(3))
print(np.random.random((3,2)))
# Out:
# 0.9888378092076436
# [0.00158816 0.08290791 0.65886814]
# [[0.37224682 0.58048274]
#  [0.06563924 0.77828237]
#  [0.57365834 0.51323891]]
