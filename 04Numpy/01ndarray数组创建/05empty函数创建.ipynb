# %%
"""
    该函数的作用就是创建一个指定形状、数据类型且未初始化的数组，函数原型是:
    numpy.empty(shape, dtype=float, order='C')

    注意；empty不初始化数组元素，因此比其他函数创建更快，但数组中的值是未定义的，可能包含任何值
        在使用numpy.empty创建数组后，应有效填充数组，以避免使用未定义的数据快
"""


import numpy as np
# 创建一个10个1的数组
print(np.empty(10,dtype=np.float32))
# Out:
# [2.7643496e+38 8.7020635e-43 3.0300525e+38 8.7020635e-43 2.0669244e+09
#  1.7221958e-41 0.0000000e+00 8.7020635e-43 1.8985688e+28 5.2164842e-11]
