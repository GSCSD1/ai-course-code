# %%
import pandas as pd
df =  pd.read_csv('班级成绩单.csv')
display(df)
# Out:
#    编号  姓名  年龄  成绩
# 0   1  小明  50  78
# 1   2  小刚  21  64
# 2   3  小红  19  89

# %%
# 写入
import pandas as pd
data={
    '编号':[1,2,3],
    '姓名':['小明','小刚','小红'],
    '年龄':[1,2,3],
    '成绩':[100,64,89]
}
df = pd.DataFrame(data)

df.to_csv('班级成绩单.csv',index=False,encoding='utf-8')
