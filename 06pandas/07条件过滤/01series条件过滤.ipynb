# %%
import numpy as np
import pandas as pd
s1 = pd.Series([1,5,3,np.nan,None,13,76])

print(s1)
print(s1[s1>=3])
# Out:
# 0     1.0
# 1     5.0
# 2     3.0
# 3     NaN
# 4     NaN
# 5    13.0
# 6    76.0
# dtype: float64
# 1     5.0
# 2     3.0
# 5    13.0
# 6    76.0
# dtype: float64

# %%
print(s1[pd.Series([False,True,True,False,False,True,True])])
# Out:
# 1     5.0
# 2     3.0
# 5    13.0
# 6    76.0
# dtype: float64

# %%
# 筛选出大于等于5，小于76
condition = (s1>=5) & (s1<76)
print(s1[condition])
# Out:
# 1     5.0
# 5    13.0
# dtype: float64
